# %%
import pandas as pd

# %%
# read parquet file
data = pd.read_parquet("data/resample.parquet")

# %%
data
# Out:
#          Accelerometer_x  Accelerometer_y  Accelerometer_z  Gyroscope_x  \
# 0               0.856745        -9.736820         0.020757     0.268116
# 1               0.336442        -7.226947         2.845873     0.084436
# 2              -1.977320        -5.265067         5.953660    -0.817032
# 3              -5.969138        -0.849210         3.988554    -1.020396
# 4             -16.252441        16.919327        -5.084396     0.824533
# ...                  ...              ...              ...          ...
# 2157404         2.245690       -18.256710         2.483854    -3.412629
# 2157405         9.969309       -17.934803         3.881573    -2.368905
# 2157406        15.270597       -13.038113         7.037325    -1.447964
# 2157407         3.578034       -10.812859         7.249442    -0.878516
# 2157408        -4.368380        -5.661316         7.183708    -0.454698
#
#          Gyroscope_y  Gyroscope_z  Magnetometer_x  Magnetometer_y  \
# ...

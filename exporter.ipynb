# %% [markdown]
# # Imports and settings
# ---
# Setup for using the pipelines

# %%
from utils import manager

import polars as pl

# %% [markdown]
# # Without Pipeline
# ---
# Get data from SensorLogger App without processing

# %%
path = "../data/"
pipeline = None
resample_freq_hz = 100
origin = "SensorLogger"

data = manager.PipelineRunner(path, pipeline, resample_freq_hz, origin).run()
data
# Out:
# shape: (289038, 7)
# ┌──────────────┬──────────────┬──────────────┬──────────────┬──────────────┬──────────┬────────────┐
# │ time         ┆ Acceleromete ┆ Acceleromete ┆ Acceleromete ┆ id           ┆ person   ┆ activity   │
# │ ---          ┆ r_x          ┆ r_y          ┆ r_z          ┆ ---          ┆ ---      ┆ ---        │
# │ datetime[ms] ┆ ---          ┆ ---          ┆ ---          ┆ str          ┆ str      ┆ str        │
# │              ┆ f64          ┆ f64          ┆ f64          ┆              ┆          ┆            │
# ╞══════════════╪══════════════╪══════════════╪══════════════╪══════════════╪══════════╪════════════╡
# │ 2023-02-23   ┆ 0.746        ┆ -3.304       ┆ -9.202       ┆ 01_SamsungA2 ┆ Ben_Tran ┆ Laufen     │
# │ 15:46:13.639 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _15-46-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.755        ┆ -3.312       ┆ -9.199       ┆ 01_SamsungA2 ┆ Ben_Tran ┆ Laufen     │
# │ 15:46:13.641 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _15-46-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.756        ┆ -3.301       ┆ -9.203       ┆ 01_SamsungA2 ┆ Ben_Tran ┆ Laufen     │
# │ 15:46:13.643 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _15-46-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.732        ┆ -3.281       ┆ -9.212       ┆ 01_SamsungA2 ┆ Ben_Tran ┆ Laufen     │
# │ 15:46:13.645 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _15-46-1...  ┆          ┆            │
# │ ...          ┆ ...          ┆ ...          ┆ ...          ┆ ...          ┆ ...      ┆ ...        │
# │ 2023-02-23   ┆ 0.353        ┆ -3.166       ┆ -9.274       ┆ 02_SamsungA2 ┆ Ben_Tran ┆ Velofahren │
# │ 16:24:31.627 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _16-22-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.353        ┆ -3.166       ┆ -9.274       ┆ 02_SamsungA2 ┆ Ben_Tran ┆ Velofahren │
# │ 16:24:31.629 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _16-22-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.352        ┆ -3.166       ┆ -9.274       ┆ 02_SamsungA2 ┆ Ben_Tran ┆ Velofahren │
# │ 16:24:31.631 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _16-22-1...  ┆          ┆            │
# │ 2023-02-23   ┆ 0.35         ┆ -3.164       ┆ -9.275       ┆ 02_SamsungA2 ┆ Ben_Tran ┆ Velofahren │
# │ 16:24:31.633 ┆              ┆              ┆              ┆ 2-2023-02-23 ┆          ┆            │
# │              ┆              ┆              ┆              ┆ _16-22-1...  ┆          ┆            │
# └──────────────┴──────────────┴──────────────┴──────────────┴──────────────┴──────────┴────────────┘

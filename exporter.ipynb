# %% [markdown]
# # Imports and settings
# ---
# Setup for using the pipelines

# %%
from utils.manager import PipelineRunner

# %% [markdown]
# # Without Pipeline
# ---
# Get data from QuestDB

# %%
# set pipeline and resample frequency
pipeline = None
resample_freq_hz = 100

# run without pipeline
pipeline = PipelineRunner(pipeline=pipeline, resample_freq_hz=resample_freq_hz)
data = pipeline.run()

# print data
data
# Out:
# shape: (153237, 11)
# ┌───────────┬────────────┬────────────┬────────────┬─────┬────────┬───────────┬──────────┬─────────┐
# │ time      ┆ Accelerome ┆ Accelerome ┆ Accelerome ┆ ... ┆ filena ┆ person    ┆ activity ┆ timesta │
# │ ---       ┆ terUncalib ┆ terUncalib ┆ terUncalib ┆     ┆ me     ┆ ---       ┆ ---      ┆ mp      │
# │ datetime[ ┆ rated_x    ┆ rated_y    ┆ rated_z    ┆     ┆ ---    ┆ str       ┆ str      ┆ ---     │
# │ μs]       ┆ ---        ┆ ---        ┆ ---        ┆     ┆ str    ┆           ┆          ┆ str     │
# │           ┆ f64        ┆ f64        ┆ f64        ┆     ┆        ┆           ┆          ┆         │
# ╞═══════════╪════════════╪════════════╪════════════╪═════╪════════╪═══════════╪══════════╪═════════╡
# │ 2023-02-2 ┆ 4.545166   ┆ -8.826823  ┆ 4.315156   ┆ ... ┆ 01_Pix ┆ Florin_Ba ┆ Laufen   ┆ 2023-03 │
# │ 4 17:31:5 ┆            ┆            ┆            ┆     ┆ el6-20 ┆ rbisch    ┆          ┆ -04T16: │
# │ 4.190     ┆            ┆            ┆            ┆     ┆ 23-02- ┆           ┆          ┆ 53:01.0 │
# │           ┆            ┆            ┆            ┆     ┆ 24_17- ┆           ┆          ┆ 86346Z  │
# │           ┆            ┆            ┆            ┆     ┆ 31-22  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ 5.032405   ┆ -7.215706  ┆ 1.930559   ┆ ... ┆ 01_Pix ┆ Florin_Ba ┆ Laufen   ┆ 2023-03 │
# │ 4 17:31:5 ┆            ┆            ┆            ┆     ┆ el6-20 ┆ rbisch    ┆          ┆ -04T16: │
# │ 4.200     ┆            ┆            ┆            ┆     ┆ 23-02- ┆           ┆          ┆ 53:01.4 │
# │           ┆            ┆            ┆            ┆     ┆ 24_17- ┆           ┆          ┆ 97503Z  │
# │           ┆            ┆            ┆            ┆     ┆ 31-22  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ 5.586643   ┆ -5.900342  ┆ -4.839484  ┆ ... ┆ 01_Pix ┆ Florin_Ba ┆ Laufen   ┆ 2023-03 │
# │ 4 17:31:5 ┆            ┆            ┆            ┆     ┆ el6-20 ┆ rbisch    ┆          ┆ -04T16: │
# │ 4.210     ┆            ┆            ┆            ┆     ┆ 23-02- ┆           ┆          ┆ 53:01.0 │
# │           ┆            ┆            ┆            ┆     ┆ 24_17- ┆           ┆          ┆ 86947Z  │
# │           ┆            ┆            ┆            ┆     ┆ 31-22  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ 3.876522   ┆ -6.761817  ┆ -3.505784  ┆ ... ┆ 01_Pix ┆ Florin_Ba ┆ Laufen   ┆ 2023-03 │
# │ 4 17:31:5 ┆            ┆            ┆            ┆     ┆ el6-20 ┆ rbisch    ┆          ┆ -04T16: │
# │ 4.220     ┆            ┆            ┆            ┆     ┆ 23-02- ┆           ┆          ┆ 53:01.0 │
# │           ┆            ┆            ┆            ┆     ┆ 24_17- ┆           ┆          ┆ 86955Z  │
# │           ┆            ┆            ┆            ┆     ┆ 31-22  ┆           ┆          ┆         │
# │ ...       ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...    ┆ ...       ┆ ...      ┆ ...     │
# │ 2023-02-2 ┆ -0.515091  ┆ -1.383698  ┆ 0.302216   ┆ ... ┆ 02_iPh ┆ Gabriel_T ┆ Laufen   ┆ 2023-03 │
# │ 4 13:15:0 ┆            ┆            ┆            ┆     ┆ one13P ┆ orres     ┆          ┆ -04T17: │
# │ 8.900     ┆            ┆            ┆            ┆     ┆ roMax- ┆           ┆          ┆ 03:47.6 │
# │           ┆            ┆            ┆            ┆     ┆ 2023-0 ┆           ┆          ┆ 90843Z  │
# │           ┆            ┆            ┆            ┆     ┆ 2-24_1 ┆           ┆          ┆         │
# │           ┆            ┆            ┆            ┆     ┆ 3-...  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ -0.237457  ┆ -1.320831  ┆ 0.230392   ┆ ... ┆ 02_iPh ┆ Gabriel_T ┆ Laufen   ┆ 2023-03 │
# │ 4 13:15:0 ┆            ┆            ┆            ┆     ┆ one13P ┆ orres     ┆          ┆ -04T17: │
# │ 8.910     ┆            ┆            ┆            ┆     ┆ roMax- ┆           ┆          ┆ 03:47.6 │
# │           ┆            ┆            ┆            ┆     ┆ 2023-0 ┆           ┆          ┆ 90854Z  │
# │           ┆            ┆            ┆            ┆     ┆ 2-24_1 ┆           ┆          ┆         │
# │           ┆            ┆            ┆            ┆     ┆ 3-...  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ -0.031906  ┆ -1.187958  ┆ -0.042053  ┆ ... ┆ 02_iPh ┆ Gabriel_T ┆ Laufen   ┆ 2023-03 │
# │ 4 13:15:0 ┆            ┆            ┆            ┆     ┆ one13P ┆ orres     ┆          ┆ -04T17: │
# │ 8.920     ┆            ┆            ┆            ┆     ┆ roMax- ┆           ┆          ┆ 03:47.6 │
# │           ┆            ┆            ┆            ┆     ┆ 2023-0 ┆           ┆          ┆ 90859Z  │
# │           ┆            ┆            ┆            ┆     ┆ 2-24_1 ┆           ┆          ┆         │
# │           ┆            ┆            ┆            ┆     ┆ 3-...  ┆           ┆          ┆         │
# │ 2023-02-2 ┆ 0.182648   ┆ -1.135712  ┆ -0.170044  ┆ ... ┆ 02_iPh ┆ Gabriel_T ┆ Laufen   ┆ 2023-03 │
# │ 4 13:15:0 ┆            ┆            ┆            ┆     ┆ one13P ┆ orres     ┆          ┆ -04T17: │
# │ 8.930     ┆            ┆            ┆            ┆     ┆ roMax- ┆           ┆          ┆ 03:47.6 │
# │           ┆            ┆            ┆            ┆     ┆ 2023-0 ┆           ┆          ┆ 90863Z  │
# │           ┆            ┆            ┆            ┆     ┆ 2-24_1 ┆           ┆          ┆         │
# │           ┆            ┆            ┆            ┆     ┆ 3-...  ┆           ┆          ┆         │
# └───────────┴────────────┴────────────┴────────────┴─────┴────────┴───────────┴──────────┴─────────┘

# %% [markdown]
# # Imports and settings
# ---
# Setup for using the pipelines

# %%
from utils.manager import PipelineRunner

# %% [markdown]
# # Without Pipeline
# ---
# Get data from QuestDB

# %%
# set pipeline and resample frequency
pipeline = None
resample_freq_hz = 100

# run without pipeline
pipeline = PipelineRunner(pipeline=pipeline, resample_freq_hz=resample_freq_hz)
data = pipeline.run()

# print data
data
# Out:
# shape: (4440, 11)
# ┌─────────┬────────────┬────────────┬────────────┬─────┬──────────┬──────────┬──────────┬──────────┐
# │ timesta ┆ Accelerome ┆ Accelerome ┆ Accelerome ┆ ... ┆ filename ┆ person   ┆ activity ┆ hash     │
# │ mp      ┆ terUncalib ┆ terUncalib ┆ terUncalib ┆     ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ ---     ┆ rated_x    ┆ rated_y    ┆ rated_z    ┆     ┆ str      ┆ str      ┆ str      ┆ str      │
# │ datetim ┆ ---        ┆ ---        ┆ ---        ┆     ┆          ┆          ┆          ┆          │
# │ e[μs]   ┆ f32        ┆ f32        ┆ f32        ┆     ┆          ┆          ┆          ┆          │
# ╞═════════╪════════════╪════════════╪════════════╪═════╪══════════╪══════════╪══════════╪══════════╡
# │ 1970-01 ┆ -2.577     ┆ -6.63495   ┆ -1.13205   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 34570   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ -2.52405   ┆ -6.117     ┆ -1.75305   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 34580   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ -2.72505   ┆ -5.67495   ┆ -1.815     ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 34590   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ -2.72505   ┆ -5.40405   ┆ -1.743     ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 34600   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ ...     ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...      ┆ ...      ┆ ...      ┆ ...      │
# │ 1970-01 ┆ -1.203     ┆ -8.78205   ┆ 1.81395    ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 78930   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ 1.60995    ┆ -9.56505   ┆ 5.532      ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 78940   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ 1.77       ┆ -9.484051  ┆ 5.01       ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 78950   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 1970-01 ┆ 0.85305    ┆ -8.667001  ┆ 3.492      ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ e776d47d │
# │ -20 09: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 231d4224 │
# │ 58:30.1 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ 9baac621 │
# │ 78960   ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ 4ca06d4c │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# └─────────┴────────────┴────────────┴────────────┴─────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# # Imports and settings
# ---
# Setup for using the pipelines

# %%
from utils.manager import PipelineRunner

# %% [markdown]
# # Without Pipeline
# ---
# Get data from QuestDB

# %%
# set pipeline and resample frequency
pipeline = None
resample_freq_hz = 100

# run without pipeline
pipeline = PipelineRunner(pipeline=pipeline, resample_freq_hz=resample_freq_hz)
data = pipeline.run()

# print data
data
# Out:
# shape: (4495, 11)
# ┌─────────┬────────────┬────────────┬────────────┬─────┬──────────┬──────────┬──────────┬──────────┐
# │ timesta ┆ Accelerome ┆ Accelerome ┆ Accelerome ┆ ... ┆ filename ┆ person   ┆ activity ┆ hash     │
# │ mp      ┆ terUncalib ┆ terUncalib ┆ terUncalib ┆     ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ ---     ┆ rated_x    ┆ rated_y    ┆ rated_z    ┆     ┆ str      ┆ str      ┆ str      ┆ str      │
# │ datetim ┆ ---        ┆ ---        ┆ ---        ┆     ┆          ┆          ┆          ┆          │
# │ e[μs]   ┆ f32        ┆ f32        ┆ f32        ┆     ┆          ┆          ┆          ┆          │
# ╞═════════╪════════════╪════════════╪════════════╪═════╪══════════╪══════════╪══════════╪══════════╡
# │ 2023-02 ┆ -0.37395   ┆ -9.37395   ┆ -3.89805   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:13.3 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 10      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ -0.76395   ┆ -9.340051  ┆ -3.816     ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:13.3 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 20      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ -1.071     ┆ -9.10305   ┆ -3.77595   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:13.3 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 30      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ -1.11195   ┆ -8.979     ┆ -3.89295   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:13.3 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 40      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ ...     ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...      ┆ ...      ┆ ...      ┆ ...      │
# │ 2023-02 ┆ 2.79195    ┆ -9.591001  ┆ -1.59405   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:58.2 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 20      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ 3.02505    ┆ -8.77005   ┆ -0.804     ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:58.2 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 30      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ 2.80695    ┆ -7.959001  ┆ -0.35205   ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:58.2 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 40      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# │ 2023-02 ┆ 2.38305    ┆ -7.848001  ┆ 0.483      ┆ ... ┆ 01_Samsu ┆ Ben_Tran ┆ Laufen   ┆ acd6094c │
# │ -27 15: ┆            ┆            ┆            ┆     ┆ ngA22-20 ┆          ┆          ┆ 00bc4944 │
# │ 02:58.2 ┆            ┆            ┆            ┆     ┆ 23-02-27 ┆          ┆          ┆ b1ab7cb0 │
# │ 50      ┆            ┆            ┆            ┆     ┆ _15-02-0 ┆          ┆          ┆ a710c237 │
# │         ┆            ┆            ┆            ┆     ┆ ...      ┆          ┆          ┆          │
# └─────────┴────────────┴────────────┴────────────┴─────┴──────────┴──────────┴──────────┴──────────┘

# %%
from utils import manager

# %% [markdown]
# # Pipeline Alpha

# %%
path = "../data/"
pipeline = None
resample_freq_hz = 100
origin = "SensorLogger"

manager.PipelineRunner(path, pipeline, resample_freq_hz, origin).run()
# Out:
# Error processing ../data/Velofahren/Ben_Tran/03_SamsungA22-2023-02-23_16-25-16.json: BindingsError: "ComputeError(Owned(\"InvalidEOF\"))"
# Error processing ../data/Velofahren/Ben_Tran/04_SamsungA22-2023-02-23_16-29-55.json: BindingsError: "ComputeError(Owned(\"InvalidEOF\"))"
# Error processing ../data/Velofahren/Florin_Barbisch/Velöli_vom_bahnhof_hei-2023-02-23_17-30-57.json: BindingsError: "ComputeError(Owned(\"InvalidEOF\"))"
# shape: (475335, 58)
# ┌───┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ t ┆ Accelerome ┆ Accelerome ┆ Gravity_se ┆ ... ┆ Barometer_ ┆ Barometer_ ┆ Barometer_ ┆ Location_a │
# │ i ┆ ter_second ┆ terUncalib ┆ conds_elap ┆     ┆ seconds_el ┆ relativeAl ┆ pressure   ┆ ltitudeAbo │
# │ m ┆ s_elapsed  ┆ rated_seco ┆ sed        ┆     ┆ apsed      ┆ titude     ┆ ---        ┆ veMeanSeaL │
# │ e ┆ ---        ┆ nd...      ┆ ---        ┆     ┆ ---        ┆ ---        ┆ f64        ┆ ev...      │
# ...

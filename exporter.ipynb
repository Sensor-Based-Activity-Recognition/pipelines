# %% [markdown]
# # Imports and settings
# ---
# Setup for using the pipelines

# %%
from utils.manager import PipelineRunner

# %% [markdown]
# # Without Pipeline
# ---
# Get data from QuestDB

# %%
# set pipeline and resample frequency
pipeline = None
calibrated_data = True
resample_freq_hz = 100

# run without pipeline
pipeline = PipelineRunner(pipeline=pipeline, resample_freq_hz=resample_freq_hz, calibrated_data=calibrated_data)
data = pipeline.run()

# print data
data
# Out:
# shape: (4314657, 12)
# ┌─────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬──────────┬─────┐
# │ timesta ┆ Accelerome ┆ Accelerome ┆ Accelerome ┆ ... ┆ Magnetomet ┆ Magnetomet ┆ activity ┆ has │
# │ mp      ┆ ter_x      ┆ ter_y      ┆ ter_z      ┆     ┆ er_y       ┆ er_z       ┆ ---      ┆ h   │
# │ ---     ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---        ┆ str      ┆ --- │
# │ datetim ┆ f32        ┆ f32        ┆ f32        ┆     ┆ f32        ┆ f32        ┆          ┆ str │
# │ e[μs]   ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆     │
# ╞═════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪══════════╪═════╡
# │ 2023-03 ┆ 0.856745   ┆ -9.73682   ┆ 0.020757   ┆ ... ┆ 35.951828  ┆ -0.945442  ┆ Rennen   ┆ 040 │
# │ -16 15: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ d27 │
# │ 50:20.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ bca │
# │ 60      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 3b8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 198 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a2a │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a11 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 29e │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4c8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ ac  │
# │ 2023-03 ┆ 0.909825   ┆ -8.220062  ┆ 1.002787   ┆ ... ┆ 35.816177  ┆ -1.256371  ┆ Rennen   ┆ 040 │
# │ -16 15: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ d27 │
# │ 50:20.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ bca │
# │ 70      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 3b8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 198 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a2a │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a11 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 29e │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4c8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ ac  │
# │ 2023-03 ┆ 0.336442   ┆ -7.226947  ┆ 2.845873   ┆ ... ┆ 35.596741  ┆ -1.602486  ┆ Rennen   ┆ 040 │
# │ -16 15: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ d27 │
# │ 50:20.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ bca │
# │ 80      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 3b8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 198 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a2a │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a11 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 29e │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4c8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ ac  │
# │ 2023-03 ┆ -0.488674  ┆ -6.452185  ┆ 5.054952   ┆ ... ┆ 35.198273  ┆ -1.386124  ┆ Rennen   ┆ 040 │
# │ -16 15: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ d27 │
# │ 50:20.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ bca │
# │ 90      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 3b8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 198 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a2a │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a11 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 29e │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4c8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ ac  │
# │ ...     ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...      ┆ ... │
# │ 2023-03 ┆ 3.578034   ┆ -10.812859 ┆ 7.249442   ┆ ... ┆ 24.66      ┆ 24.24      ┆ Rennen   ┆ ff3 │
# │ -12 13: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │ 25:03.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ c19 │
# │ 80      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ eb8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 458 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ fba │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 1a6 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 68b │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 8a7 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a94 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 24  │
# │ 2023-03 ┆ -0.935012  ┆ -8.310925  ┆ 6.780705   ┆ ... ┆ 23.4       ┆ 25.379999  ┆ Rennen   ┆ ff3 │
# │ -12 13: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │ 25:03.6 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ c19 │
# │ 90      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ eb8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 458 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ fba │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 1a6 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 68b │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 8a7 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a94 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 24  │
# │ 2023-03 ┆ -4.36838   ┆ -5.661316  ┆ 7.183708   ┆ ... ┆ 21.66      ┆ 26.76      ┆ Rennen   ┆ ff3 │
# │ -12 13: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │ 25:03.7 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ c19 │
# │ 00      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ eb8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 458 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ fba │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 1a6 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 68b │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 8a7 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a94 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 24  │
# │ 2023-03 ┆ -8.319786  ┆ -0.731302  ┆ 8.710353   ┆ ... ┆ 20.879999  ┆ 28.5       ┆ Rennen   ┆ ff3 │
# │ -12 13: ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 4ad │
# │ 25:03.7 ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ c19 │
# │ 10      ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ eb8 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 458 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ fba │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 1a6 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 68b │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 8a7 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ a94 │
# │         ┆            ┆            ┆            ┆     ┆            ┆            ┆          ┆ 24  │
# └─────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴──────────┴─────┘
